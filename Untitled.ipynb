# %%
import pandas as pd 
df = pd.read_csv("pizzas.csv")
df
# Out:
#    diametro  preco
# 0        20     50
# 1        25     65
# 2        30     80
# 3        35    100
# 4        40    120
# 5        45    140
# 6        50    160

# %%
df.plot(kind="scatter", x="diametro", y="preco");

# %%
from sklearn import linear_model
modelo = linear_model.LinearRegression()
x = df[["diametro"]]
y = df[["preco"]]

modelo.fit(x, y)
# Out:
# LinearRegression()

# %%
print (modelo.predict([[20]])[0][0])
# Out:
# 46.428571428571416
# c:\Users\55119\AppData\Local\pypoetry\Cache\virtualenvs\projeto-ml-kB3PvR3F-py3.13\Lib\site-packages\sklearn\utils\validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
